# %% [markdown]
# # LLM 10K Document Analysis
# #### By: Jeffrey Potvin
# #### Summary:
#
# This script automates the extraction of new product information from SEC 10-K filings for a set of S&P 500 companies. It performs the following steps:
#
# 1. **Load Data:**
#    Reads a CSV file containing company data (including CIK, ticker, and market cap) from the WIKI_COMPANY_SCRAPE_CSV.py script.
#    **Note:**
#    This was done to save time during testing. The CSV is provided but you could pull some different subsets of companys using the provided WIKI_COMPANY_SCRAPE_CSV.py script.
# 2. **Fetch Filings:**
#    Retrieves the latest 10-K filing for each company from the SEC EDGAR database.
#
# 3. **Clean Text:**
#    Cleans the raw filing text by removing HTML, URLs, extraneous numbers, and boilerplate language to prepare it for LLM analysis.
#
# 4. **Extract Products:**
#    Sends the cleaned text to the GPT-4O-MINI model via the OpenAI client to extract new product names and descriptions in JSON format. The script then parses the JSON output.
#
# 5. **Save Output:**
#    Writes the extracted product information along with company details to an output CSV file.
#
# **Note:**
# This script features robust error handling throughout, ensuring that network issues, parsing errors, and API errors are properly managed and logged.

# %%
import requests
import re
import os
import pandas as pd
from bs4 import BeautifulSoup
import openai
import json
import csv

# -------------------- SETTINGS -------------------- #
openai.api_key = "YOUR API KEY"                                             # Replace with your OPENAI API KEY
HEADERS = {"User-Agent": "YOUR NAME (YOUREMAIL@example.com)"}               # Replace with your name and email
SEC_API_BASE = "https://data.sec.gov/submissions/"
SEC_ARCHIVES_BASE = "https://www.sec.gov/Archives/edgar/data/"
OUTPUT_DIR = "10k_cleaned_files"                                            # Directory to save cleaned 10-K text files for reference
CSV_FILE = "sp500_companies.csv"                                            # CSV file with S&P 500 company data created with WIKI_COMPANY_SCRAPE_CSV.py
NUM_TO_PULL = 100                                                           # Number of companies to process decsending by market cap
EXTRACTED_PRODUCTS_CSV = "extracted_products.csv"                           # Output CSV file for extracted products
# -------------------------------------------------- #


# Initialize the OpenAI client
from openai import OpenAI
client = OpenAI(api_key=openai.api_key)

# -----------------------------------------------------------------
# 1) LOAD CSV & PREPARE SUBSET
# -----------------------------------------------------------------
# Define function to load the top companies by market cap from the CSV file
def load_top_companies_by_marketcap(csv_file=CSV_FILE, n=NUM_TO_PULL):
    df = pd.read_csv(csv_file, dtype={"CIK": str})
    df["Ticker"] = df["Ticker"].str.upper()
    return df.head(n)

# -----------------------------------------------------------------
# 2) GET LATEST 10-K FILING
# -----------------------------------------------------------------
# Define function to get the most recent 10-K filing for a CIK
def get_most_recent_10k_filing(cik):
    url = f"{SEC_API_BASE}CIK{cik}.json"
    response = requests.get(url, headers=HEADERS)
    if response.status_code != 200:
        print(f"Could not load data for CIK={cik} (status={response.status_code}).")
        return None, None

    data = response.json()
    forms = data["filings"]["recent"]["form"]
    for i, form in enumerate(forms):
        if form == "10-K":
            accession = data["filings"]["recent"]["accessionNumber"][i].replace("-", "")
            primary_doc = data["filings"]["recent"]["primaryDocument"][i]
            filing_date = data["filings"]["recent"]["filingDate"][i]
            filing_url = f"{SEC_ARCHIVES_BASE}{cik}/{accession}/{primary_doc}"
            return filing_url, filing_date
    return None, None

# -----------------------------------------------------------------
# 3) CLEAN FILING TEXT
# -----------------------------------------------------------------
# Define function to clean the text of a 10-K filing using BeautifulSoup and regex
def clean_filing_text(url):
    try:
        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            print(f"Filing fetch failed: HTTP {response.status_code}")
            return None

        soup = BeautifulSoup(response.text, "html.parser")
        for script_or_style in soup(["script", "style"]):
            script_or_style.extract()

        text = soup.get_text(separator="\n")
        # Remove URLs
        text = re.sub(r"http[s]?://\S+", "", text)
        # Remove 4 and higher digit numbers to avoid confusing the LLM
        text = re.sub(r"\b\d{4,}\b", "", text)
        # Remove certain tags
        text = re.sub(r"\b(document|entity|dei|us-gaap|iso4217|xbrli|country):\S+\b", "", text, flags=re.IGNORECASE)

        # Attempt to find the start of the main content
        match = re.search(r"(Item 1\..*?Business|Item 7\..*?Management’s Discussion)",
                          text, re.DOTALL | re.IGNORECASE)
        if match:
            text = text[match.start():]

        # Remove boilerplate words
        text = re.sub(r"\b(pursuant to|section|reporting period|incorporated by reference|exhibit|schedule|part ii|part iii)\b",
                      "", text, flags=re.IGNORECASE)
        # Remove excess whitespace
        text = re.sub(r"\s+", " ", text).strip()
        # Remove nonprintable characters
        text = re.sub(r"[^\x20-\x7E]+", "", text)
        return text
    except Exception as e:
        print(f"Error in clean_filing_text: {e}")
        return None

# -----------------------------------------------------------------
# 4) USE GPT-4O-MINI TO EXTRACT NEW PRODUCTS
# -----------------------------------------------------------------
# Define function to extract new products from a 10-K text using GPT-4O-Mini
def extract_new_products(text):
    # Define the prompts for the GPT-4O-Mini model
    system_prompt = (
        "You are a world-class information extraction assistant. "
        "Given an excerpt of a 10-K SEC filing, identify references to any newly introduced "
        "or recently launched products. Return a JSON array of objects, each with "
        "'product_name' and 'product_description'. If no new products are found, return an empty JSON array: []."
    )
    user_prompt = f"Extract any new or recently introduced products from the following 10-K text:\n\n{text}"

    try:
        # Call the OpenAI API to generate completions
        completion = client.chat.completions.create(
            model="gpt-4o-mini",  # Change this model name as needed
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt},
            ],
            temperature=0.0,
        )
        content = completion.choices[0].message.content
        
        # Debugging: Print the raw GPT output
        print("DEBUG: Raw GPT output:")
        print(content)
        
        # Remove markdown code fences if present
        if content.startswith("```"):
            lines = content.splitlines()
            # Remove the first line if it starts with triple backticks
            if lines[0].startswith("```"):
                lines = lines[1:]
            # Remove the last line if it contains only triple backticks
            if lines and lines[-1].strip() == "```":
                lines = lines[:-1]
            content = "\n".join(lines).strip()
        
        # Parse the cleaned content as JSON
        extracted_products = json.loads(content)
        if not isinstance(extracted_products, list):
            print("DEBUG: Parsed JSON is not a list.")
            return []
        
        final_products = []
        for item in extracted_products:
            product_name = item.get("product_name", "").strip()
            product_description = item.get("product_description", "").strip()
            if product_name:
                final_products.append({
                    "product_name": product_name,
                    "product_description": product_description
                })
        return final_products

    except json.JSONDecodeError as jde:
        print(f"JSON Decode Error: {jde}")
        print("Raw content from GPT after cleaning:", content)
        return []
    except Exception as e:
        print(f"GPT Extraction Error: {e}")
        return []

# -----------------------------------------------------------------
# 5) MAIN
# -----------------------------------------------------------------
# Define the main function to process the S&P 500 companies
def main():
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    # Create the CSV file with a header for extracted products
    with open(EXTRACTED_PRODUCTS_CSV, mode="w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f, delimiter='|')
        writer.writerow(["Company Name", "Stock Name", "Filing Time", "New Product", "Product Description"])

    df_subset = load_top_companies_by_marketcap(CSV_FILE, NUM_TO_PULL)
    print(f"Processing {len(df_subset)} S&P 500 companies from {CSV_FILE}...")
    # Iterate over the subset of companies
    for idx, row in df_subset.iterrows():
        ticker = row["Ticker"]
        company_name = row["Company"]
        cik = row["CIK"]
        market_cap = row.get("MarketCap", None)

        print(f"\n=== {idx+1}: {ticker} ({company_name}) - MarketCap: {market_cap} ===")
        filing_url, filing_date = get_most_recent_10k_filing(cik)
        if not filing_url:
            print("  No 10-K found. Skipping...")
            continue

        print(f"  Found 10-K: {filing_url} (Date: {filing_date})")
        cleaned_text = clean_filing_text(filing_url)
        if not cleaned_text:
            print(f"  No cleaned text for {ticker}.")
            continue

        # Save the cleaned text locally for reference
        file_name = f"10k_{ticker}.txt"
        output_path = os.path.join(OUTPUT_DIR, file_name)
        with open(output_path, "w", encoding="utf-8") as f_out:
            f_out.write(cleaned_text)
        print(f"  ✔ Saved cleaned text to: {output_path}")

        # Extract new products using GPT
        extracted_products = extract_new_products(cleaned_text)
        if extracted_products:
            print(f"  ✔ Found {len(extracted_products)} new product(s). Writing to CSV...")
            with open(EXTRACTED_PRODUCTS_CSV, mode="a", newline="", encoding="utf-8") as f:
                writer = csv.writer(f, delimiter='|')
                for product_info in extracted_products:
                    writer.writerow([
                        company_name,
                        ticker,
                        filing_date,
                        product_info["product_name"],
                        product_info["product_description"]
                    ])
        else:
            print("  No new products extracted from GPT.")

if __name__ == "__main__":
    main()
# Out:
# Processing 100 S&P 500 companies from sp500_companies.csv...
#
# === 1: AAPL (Apple Inc.) - MarketCap: 3259495350272 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000320193/000032019324000123/aapl-20240928.htm (Date: 2024-11-01)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_AAPL.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "iPhone 16",
#         "product_description": "The latest model in the iPhone line, featuring advanced technology and capabilities."
#     },
#     {
#         "product_name": "iPhone 16 Plus",
#         "product_description": "A larger version of the iPhone 16, offering enhanced display and battery life."
#     },
#     {
#         "product_name": "iPhone 16 Pro",
#         "product_description": "A premium model in the iPhone 16 series, equipped with advanced features and specifications."
#     },
#     {
#         "product_name": "iPhone 16 Pro Max",
#         "product_description": "The top-tier model in the iPhone 16 series, featuring the largest display and most advanced technology."
#     },
#     {
#         "product_name": "Apple Watch Series 10",
#         "product_description": "The latest iteration of Apple's smartwatch, featuring new health and fitness tracking capabilities."
#     },
#     {
#         "product_name": "AirPods 4",
#         "product_description": "The newest version of Apple's wireless earbuds, offering improved sound quality and battery life."
#     },
#     {
#         "product_name": "Apple Intelligence",
#         "product_description": "A personal intelligence system that uses generative models to enhance user experience."
#     },
#     {
#         "product_name": "iPad Air",
#         "product_description": "A lightweight and powerful tablet designed for versatility and performance."
#     },
#     {
#         "product_name": "iPad Pro",
#         "product_description": "A high-performance tablet aimed at professionals and creatives, featuring advanced capabilities."
#     },
#     {
#         "product_name": "iOS 18",
#         "product_description": "The latest version of Apple's mobile operating system, introducing new features and enhancements."
#     },
#     {
#         "product_name": "macOS Sequoia",
#         "product_description": "The latest version of Apple's operating system for Mac computers, featuring new functionalities."
#     },
#     {
#         "product_name": "iPadOS 18",
#         "product_description": "The latest version of the operating system designed specifically for iPads, enhancing usability."
#     },
#     {
#         "product_name": "watchOS 11",
#         "product_description": "The latest version of the operating system for Apple Watch, introducing new health and fitness features."
#     },
#     {
#         "product_name": "visionOS 2",
#         "product_description": "The latest version of the operating system for Apple's spatial computing devices."
#     },
#     {
#         "product_name": "tvOS 18",
#         "product_description": "The latest version of the operating system for Apple TV, featuring new entertainment options."
#     }
# ]
# ```
#   ✔ Found 15 new product(s). Writing to CSV...
#
# === 2: MSFT (Microsoft) - MarketCap: 2849221378048 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000789019/000095017024087843/msft-20240630.htm (Date: 2024-07-30)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_MSFT.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Copilot for Microsoft 365",
#         "product_description": "Combines AI with business data in the Microsoft Graph and Microsoft 365 applications to help organizations empower their employees."
#     },
#     {
#         "product_name": "Copilot Pro",
#         "product_description": "A consumer subscription service that offers faster and more powerful AI assistance in Microsoft 365 apps and on the web."
#     },
#     {
#         "product_name": "Copilot Studio",
#         "product_description": "Allows customers to customize Copilot for Microsoft 365 or build their own Copilot."
#     },
#     {
#         "product_name": "Copilot for Sales, Copilot for Service, and Copilot for Finance",
#         "product_description": "Role-based extensions of Microsoft Copilot that bring together the power of Copilot for Microsoft 365 with role-specific insights and workflow assistance to streamline business processes."
#     },
#     {
#         "product_name": "Windows 365",
#         "product_description": "Enables users to stream a full Windows experience from the Microsoft Cloud to any device."
#     },
#     {
#         "product_name": "Copilot+ PCs",
#         "product_description": "A new class of Windows 11 PCs that are powered by a neural processing unit, using on-device AI for enhanced performance and features."
#     },
#     {
#         "product_name": "Microsoft Fabric",
#         "product_description": "An end-to-end, unified analytics platform that brings together all the data and analytics tools that organizations need."
#     },
#     {
#         "product_name": "Copilot for Security",
#         "product_description": "An AI cybersecurity product that enables security professionals to respond to cyberthreats quickly."
#     },
#     {
#         "product_name": "Activision Blizzard",
#         "product_description": "A leader in game development and an interactive entertainment content publisher, acquired to accelerate growth in Microsoft's gaming business."
#     }
# ]
# ```
#   ✔ Found 9 new product(s). Writing to CSV...
#
# === 3: NVDA (Nvidia) - MarketCap: 2824055816192 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001045810/000104581025000023/nvda-20250126.htm (Date: 2025-02-26)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_NVDA.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "NVIDIA Blackwell architecture",
#         "product_description": "A full set of data center scale infrastructure that includes GPUs, CPUs, DPUs, interconnects, switch chips and systems, and networking adapters, excelling at processing cutting edge generative AI and accelerated computing workloads with market leading performance and efficiency."
#     },
#     {
#         "product_name": "NVIDIA GeForce RTX 50 Series",
#         "product_description": "A family of desktop and laptop GPUs that introduced neural graphics, combining AI models with traditional rendering to unlock a new era of graphics innovation, featuring the next generation of DLSS technology powered by a transformer model architecture."
#     },
#     {
#         "product_name": "NVIDIA AI Enterprise",
#         "product_description": "A comprehensive suite of enterprise-grade AI software designed to simplify the development and deployment of production-grade, end-to-end generative AI applications."
#     },
#     {
#         "product_name": "NVIDIA DGX Cloud",
#         "product_description": "A fully managed AI-training-as-a-service platform which includes cloud-based infrastructure and software for AI, customizable pretrained AI models, and access to NVIDIA experts."
#     },
#     {
#         "product_name": "NVIDIA Omniverse",
#         "product_description": "A development platform and operating system for building and running virtual world simulation applications, available as a software subscription for enterprise use and free for individual use."
#     },
#     {
#         "product_name": "NVIDIA DRIVE Hyperion",
#         "product_description": "A complete end-to-end solution for the autonomous vehicle market, consisting of high-performance, energy efficient computing hardware and a modular software platform for autonomous driving, mapping, and parking services."
#     }
# ]
# ```
#   ✔ Found 6 new product(s). Writing to CSV...
#
# === 4: AMZN (Amazon) - MarketCap: 2107776434176 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001018724/000101872425000004/amzn-20241231.htm (Date: 2025-02-07)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_AMZN.txt
# DEBUG: Raw GPT output:
# ```json
# []
# ```
#   No new products extracted from GPT.
#
# === 5: GOOGL (Alphabet Inc. (Class A)) - MarketCap: 2047465095168 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001652044/000165204425000014/goog-20241231.htm (Date: 2025-02-05)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_GOOGL.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Gemini",
#         "product_description": "A natively multimodal AI model that can generalize and seamlessly understand, operate across, and combine different types of information including text, code, audio, image, and video."
#     },
#     {
#         "product_name": "Gemini 2.0",
#         "product_description": "The most capable model yet, powering AI features across Google's products and services."
#     },
#     {
#         "product_name": "AlphaFold 3",
#         "product_description": "An AI system that predicts the structure and interactions of all the molecules in life's processes, building on previous models."
#     },
#     {
#         "product_name": "NotebookLM",
#         "product_description": "Helps users understand complex information by summarizing sources and providing relevant quotes."
#     },
#     {
#         "product_name": "Gemini for Google Workspace",
#         "product_description": "Helps users write, organize, visualize, accelerate workflows, and have richer meetings."
#     },
#     {
#         "product_name": "Pixel 9 series",
#         "product_description": "The latest generation of Pixel devices built with Gemini Nano, offering AI-assistive experiences."
#     },
#     {
#         "product_name": "Pixel Watch 3",
#         "product_description": "The latest version of Google's smartwatch, incorporating advanced features."
#     },
#     {
#         "product_name": "Gemini app",
#         "product_description": "Allows users to collaborate with new AI features that include image generation capabilities, coding support, and app integration."
#     },
#     {
#         "product_name": "Project Astra",
#         "product_description": "Research prototype exploring the future capabilities of a universal AI assistant."
#     },
#     {
#         "product_name": "Project Mariner",
#         "product_description": "An early prototype capable of taking actions in Chrome as an experimental extension."
#     }
# ]
# ```
#   ✔ Found 10 new product(s). Writing to CSV...
#
# === 6: GOOG (Alphabet Inc. (Class C)) - MarketCap: 2047451856896 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001652044/000165204425000014/goog-20241231.htm (Date: 2025-02-05)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_GOOG.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Gemini",
#         "product_description": "A natively multimodal AI model that can generalize and seamlessly understand, operate across, and combine different types of information including text, code, audio, image, and video."
#     },
#     {
#         "product_name": "Gemini 2.0",
#         "product_description": "The most capable model yet, powering AI features across Google's products and services."
#     },
#     {
#         "product_name": "AlphaFold 3",
#         "product_description": "An AI system that predicts the structure and interactions of all the molecules in life's processes, built on previous models."
#     },
#     {
#         "product_name": "NotebookLM",
#         "product_description": "Helps users understand complex information by summarizing sources and providing relevant quotes."
#     },
#     {
#         "product_name": "Gemini for Google Workspace",
#         "product_description": "Helps users write, organize, visualize, accelerate workflows, and have richer meetings."
#     },
#     {
#         "product_name": "Pixel 9 series",
#         "product_description": "The latest generation of Pixel devices built with Gemini Nano, offering AI-assistive experiences."
#     },
#     {
#         "product_name": "Pixel Watch 3",
#         "product_description": "The latest version of Google's smartwatch, incorporating advanced features."
#     },
#     {
#         "product_name": "Project Astra",
#         "product_description": "Research prototype exploring the future capabilities of a universal AI assistant."
#     },
#     {
#         "product_name": "Project Mariner",
#         "product_description": "An early prototype capable of taking actions in Chrome as an experimental extension."
#     }
# ]
# ```
#   ✔ Found 9 new product(s). Writing to CSV...
#
# === 7: META (Meta Platforms) - MarketCap: 1569754316800 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001326801/000132680125000017/meta-20241231.htm (Date: 2025-01-30)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_META.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "WhatsApp Channels",
#         "product_description": "A one-to-many broadcast service designed to help people follow information from people and organizations that are important to them."
#     },
#     {
#         "product_name": "Ray-Ban Meta AI glasses",
#         "product_description": "Glasses that feature Meta AI, an advanced conversational assistant, and other features such as hands-free interaction."
#     },
#     {
#         "product_name": "Orion prototype",
#         "product_description": "A pair of true AR glasses that overlay content on top of the physical world, featuring an industry-leading field of view and a comfortable glasses form factor."
#     },
#     {
#         "product_name": "Meta Quest devices",
#         "product_description": "Virtual reality devices that enable a range of social experiences, including gaming, fitness, and entertainment."
#     },
#     {
#         "product_name": "Meta AI",
#         "product_description": "An assistant available across Meta's apps, designed to help people learn, get things done, create content, and connect with others."
#     },
#     {
#         "product_name": "Threads",
#         "product_description": "An application for text-based updates and public conversations, where communities come together to discuss topics of interest."
#     }
# ]
# ```
#   ✔ Found 6 new product(s). Writing to CSV...
#
# === 8: BRK.B (Berkshire Hathaway) - MarketCap: 1070878359552 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001067983/000095017025025210/brka-20241231.htm (Date: 2025-02-24)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_BRK.B.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Jazwares",
#         "product_description": "A leading global toy and consumer products manufacturer with a robust portfolio of owned and licensed brands, such as Squishmallows, BLDR, Pokémon, Hello Kitty, Star Wars, Disney, BumBumz, and Adopt Me. In addition to toys, offerings also include virtual games, costumes, and products for pets."
#     },
#     {
#         "product_name": "Pilot Travel Centers",
#         "product_description": "Operates travel centers and fuel-only retail locations across the U.S. and in five Canadian provinces, primarily under the names Pilot or Flying J, as well as large wholesale fuel and fuel marketing businesses in the U.S."
#     }
# ]
# ```
#   ✔ Found 2 new product(s). Writing to CSV...
#
# === 9: AVGO (Broadcom) - MarketCap: 913255825408 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001730168/000173016824000139/avgo-20241103.htm (Date: 2024-12-20)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_AVGO.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "VMware Cloud Foundation",
#         "product_description": "A private cloud platform that integrates compute, storage, networking, and management into a single solution, providing license portability and enabling customers to modernize infrastructure and accelerate developer productivity with greater resilience and security."
#     },
#     {
#         "product_name": "Seagate SoC Operations",
#         "product_description": "Acquired certain assets related to the design, development, and manufacture of System-on-Chip (SoC) operations to strengthen the portfolio of SoC products."
#     }
# ]
# ```
#   ✔ Found 2 new product(s). Writing to CSV...
#
# === 10: TSLA (Tesla, Inc.) - MarketCap: 797986390016 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001318605/000162828025003063/tsla-20241231.htm (Date: 2025-01-30)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_TSLA.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Cybertruck",
#         "product_description": "A full-size electric pickup truck with a stainless steel exterior that has the utility and strength of a truck while featuring the speed of a sports car. First deliveries began in November."
#     },
#     {
#         "product_name": "Tesla Semi",
#         "product_description": "A commercial electric vehicle that began early production and deliveries in 2023."
#     },
#     {
#         "product_name": "Cybercab",
#         "product_description": "A purpose-built Robotaxi product leveraging developments in proprietary Full Self-Driving (FSD) technology."
#     },
#     {
#         "product_name": "Powerwall 3",
#         "product_description": "An energy storage product that is part of the company's efforts to ramp production and increase market penetration."
#     }
# ]
# ```
#   ✔ Found 4 new product(s). Writing to CSV...
#
# === 11: LLY (Lilly (Eli)) - MarketCap: 738169978880 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000059478/000005947825000067/lly-20241231.htm (Date: 2025-02-19)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_LLY.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "LillyDirect",
#         "product_description": "A direct-to-consumer digital health care platform designed to provide patients in the U.S. living with obesity, migraine, and diabetes with tools to help them access care from independent healthcare providers, as well as the option for home delivery of select prescribed Lilly medicines through third-party pharmacies."
#     },
#     {
#         "product_name": "Zepbound",
#         "product_description": "For the treatment of adults with obesity or overweight with at least one weight-related comorbid condition in combination with a reduced-calorie diet and increased physical activity; and for the treatment of moderate to severe obstructive sleep apnea in adults with obesity in combination with a reduced-calorie diet and increased physical activity."
#     },
#     {
#         "product_name": "Mounjaro",
#         "product_description": "A glucose-dependent insulinotropic polypeptide and glucagon-like peptide-1 receptor agonist, for the treatment of adults with type 2 diabetes in combination with diet and exercise to improve glycemic control."
#     },
#     {
#         "product_name": "Kisunla",
#         "product_description": "For adults with early symptomatic Alzheimer's disease with confirmed amyloid pathology and with mild cognitive impairment or mild dementia stage of disease."
#     },
#     {
#         "product_name": "Jaypirca",
#         "product_description": "For the treatment of adult patients with relapsed or refractory mantle cell lymphoma after at least two lines of systemic therapy, including a BTK inhibitor; and for the treatment of adult patients with chronic lymphocytic leukemia or small lymphocytic lymphoma who have received at least two prior lines of therapy, including a BTK inhibitor and a BCL-2 inhibitor."
#     },
#     {
#         "product_name": "Omvoh",
#         "product_description": "For the treatment of moderately to severely active ulcerative colitis in adults and for the treatment of moderately to severely active Crohn's disease in adults."
#     },
#     {
#         "product_name": "Ebglyss",
#         "product_description": "For the treatment of adult and adolescent patients 12 years or older with moderate to severe atopic dermatitis."
#     },
#     {
#         "product_name": "Donanemab",
#         "product_description": "Submitted for regulatory review in the EU for the treatment of early Alzheimer's disease."
#     },
#     {
#         "product_name": "Imlunestrant",
#         "product_description": "Submitted for regulatory review in the U.S., the EU, and Japan for the treatment of ER-positive HER2-negative metastatic breast cancer."
#     }
# ]
# ```
#   ✔ Found 9 new product(s). Writing to CSV...
#
# === 12: WMT (Walmart) - MarketCap: 684444811264 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000104169/000010416925000021/wmt-20250131.htm (Date: 2025-03-14)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_WMT.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "VIZIO Holding Corp.",
#         "product_description": "Acquired in December for net cash consideration of $1.9 billion, VIZIO collects certain consumer data, including television viewing data."
#     },
#     {
#         "product_name": "ONE",
#         "product_description": "A fintech venture that offers various services such as money transfers, digital payment platforms, bill payment, money orders, check cashing, prepaid access, co-branded credit cards, installment lending, and earned wage access."
#     }
# ]
# ```
#   ✔ Found 2 new product(s). Writing to CSV...
#
# === 13: V (Visa Inc.) - MarketCap: 642051670016 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001403161/000140316124000058/v-20240930.htm (Date: 2024-11-13)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_V.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Visa+",
#         "product_description": "Visa+ enables transfers between participating P2P apps, providing reach, flexibility, and convenience to P2P payment experiences."
#     },
#     {
#         "product_name": "Accounts Receivable Manager",
#         "product_description": "A virtual card automation solution in the U.S. designed to streamline accounts receivable processes."
#     },
#     {
#         "product_name": "Visa Token Service (VTS)",
#         "product_description": "Enhances the digital ecosystem through improved authorization, reduced fraud, and improved consumer experience by replacing 16-digit Visa account numbers with a token."
#     },
#     {
#         "product_name": "Click to Pay",
#         "product_description": "Provides a simplified and more consistent cardholder checkout experience online by removing time-consuming key entry of personal information."
#     },
#     {
#         "product_name": "Visa Commercial Solutions",
#         "product_description": "A suite of tailored solutions for businesses to manage working capital and drive efficiency in B2B payments."
#     },
#     {
#         "product_name": "Visa Direct",
#         "product_description": "Facilitates domestic and cross-border money movement, enabling clients to collect, convert, hold, and send funds across Visa's network."
#     },
#     {
#         "product_name": "Visa Protect",
#         "product_description": "A suite of solutions designed to reduce fraud across immediate account-to-account and card-not-present payments."
#     },
#     {
#         "product_name": "Visa Protect for A2A Payments",
#         "product_description": "The first fraud prevention solution built specifically for real-time non-card payments."
#     },
#     {
#         "product_name": "Visa Deep Authorization",
#         "product_description": "An AI-powered transaction risk scoring solution tailored to better manage card-not-present payments."
#     }
# ]
# ```
#   ✔ Found 9 new product(s). Writing to CSV...
#
# === 14: JPM (JPMorgan Chase) - MarketCap: 637233463296 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000019617/000001961725000270/jpm-20241231.htm (Date: 2025-02-14)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_JPM.txt
#   ❌ GPT Extraction Error: Error code: 429 - {'error': {'message': 'Request too large for gpt-4o-mini in organization org-PMyKV597a0bS1G4IezkF85A5 on tokens per min (TPM): Limit 200000, Requested 296463. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#   No new products extracted from GPT.
#
# === 15: MA (Mastercard) - MarketCap: 478318526464 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001141391/000114139125000011/ma-20241231.htm (Date: 2025-02-12)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_MA.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Mastercard Move",
#         "product_description": "A collection of money movement capabilities that provides solutions for money transfers to consumers from consumers, businesses or governments."
#     },
#     {
#         "product_name": "Alias-Based Remittances and Payouts platform",
#         "product_description": "Designed to remove the friction of manually capturing required information to complete cross-border remittances and disbursements, simplifying the experience for both senders and receivers."
#     },
#     {
#         "product_name": "Tap on Phone acceptance technology",
#         "product_description": "Enables businesses of all sizes to accept payments from any contactless card or mobile wallet directly from their device, providing a turnkey and cost-effective solution without any additional hardware required."
#     },
#     {
#         "product_name": "Mastercard Digital First program",
#         "product_description": "Enables issuing customers to offer their cardholders a fully digital payment experience with an optional physical card, securing purchases and managing alerts, controls, and benefits."
#     },
#     {
#         "product_name": "Click to Pay",
#         "product_description": "A checkout experience designed to provide consumers convenience and security in a digital environment, making it easier for merchants to implement secure digital payments."
#     }
# ]
# ```
#   ✔ Found 5 new product(s). Writing to CSV...
#
# === 16: XOM (ExxonMobil) - MarketCap: 473530335232 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000034088/000003408825000010/xom-20241231.htm (Date: 2025-02-19)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_XOM.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Proxxima TM systems",
#         "product_description": "Advanced polyolefin thermoset resin that uses components of gasoline and catalyst technology to create a material that is lighter, stronger, and more durable than conventional products, providing alternatives for the construction, coatings, and transportation industries."
#     },
#     {
#         "product_name": "Low Carbon Solutions",
#         "product_description": "A business unit focused on developing and deploying technologies for carbon capture and storage, hydrogen, lower-emission fuels, and lithium."
#     }
# ]
# ```
#   ✔ Found 2 new product(s). Writing to CSV...
#
# === 17: UNH (UnitedHealth Group) - MarketCap: 440077090816 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000731766/000073176625000063/unh-20241231.htm (Date: 2025-02-27)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_UNH.txt
# DEBUG: Raw GPT output:
# ```json
# []
# ```
#   No new products extracted from GPT.
#
# === 18: ORCL (Oracle Corporation) - MarketCap: 423130234880 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001341439/000095017024075605/orcl-20240531.htm (Date: 2024-06-20)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_ORCL.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Oracle Fusion Cloud Enterprise Resource Planning (ERP)",
#         "product_description": "A strategic suite of applications foundational to facilitating and extracting more business value out of the adoption of other Oracle SaaS offerings."
#     },
#     {
#         "product_name": "Oracle Fusion Cloud Enterprise Performance Management (EPM)",
#         "product_description": "Designed to analyze financial performance, drive accurate and agile financial plans, optimize the financial close and consolidation process, streamline account reconciliation and satisfy an organization's reporting requirements."
#     },
#     {
#         "product_name": "Oracle Fusion Cloud Supply Chain and Manufacturing Management (SCM)",
#         "product_description": "Helps organizations create, optimize and digitize their supply chains."
#     },
#     {
#         "product_name": "Oracle Fusion Cloud Human Capital Management (HCM)",
#         "product_description": "Designed to help organizations find, develop and retain their talent, enable collaboration, provide workforce insights, improve business process efficiency and enable users to connect to an integrated suite of HCM applications."
#     },
#     {
#         "product_name": "Oracle Fusion Sales, Service and Marketing",
#         "product_description": "Modules designed to be complete and integrated solutions to help organizations deliver consistent and personalized customer experiences across their customer channels."
#     },
#     {
#         "product_name": "NetSuite Applications Suite",
#         "product_description": "A unified, cloud-based applications suite to run a company's entire business, including financials and ERP, customer relationship management, human resources, professional services and commerce."
#     },
#     {
#         "product_name": "Oracle Cerner healthcare applications",
#         "product_description": "Designed to enable medical professionals to deliver better healthcare to individual patients and communities."
#     },
#     {
#         "product_name": "Oracle Autonomous Database",
#         "product_description": "Delivers performance and scale for enterprise database workloads with automated database operations and policy- and machine learning-driven optimization."
#     },
#     {
#         "product_name": "Oracle MySQL HeatWave",
#         "product_description": "Combines transactions, real-time analytics, machine learning and generative AI in one managed cloud service."
#     },
#     {
#         "product_name": "Oracle Exadata Cloud@Customer",
#         "product_description": "Enables customers to run Oracle Autonomous Database and Oracle Database securely in their own data centers behind their firewalls while having the services managed by Oracle."
#     },
#     {
#         "product_name": "OCI Dedicated Region",
#         "product_description": "Enables customers to bring a self-contained OCI instance into their data centers while accessing a substantial portfolio of OCI and Oracle Cloud SaaS offerings."
#     },
#     {
#         "product_name": "OCI Sovereign Cloud",
#         "product_description": "Allows customers to utilize OCI services while addressing customer latency requirements and restrictions imposed upon customers that operate in certain regulated industries."
#     },
#     {
#         "product_name": "Oracle Alloy",
#         "product_description": "Engineered to enable partners to control the commercial and customer experience to address their specific market needs for cloud services."
#     },
#     {
#         "product_name": "Oracle Roving Edge Infrastructure",
#         "product_description": "Designed to enable customers to access cloud computing and storage services at the edge of networks and in generally disconnected locations."
#     }
# ]
# ```
#   ✔ Found 14 new product(s). Writing to CSV...
#
# === 19: COST (Costco) - MarketCap: 411373207552 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000909832/000090983224000049/cost-20240901.htm (Date: 2024-10-09)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_COST.txt
# DEBUG: Raw GPT output:
# ```json
# []
# ```
#   No new products extracted from GPT.
#
# === 20: PG (Procter & Gamble) - MarketCap: 394802364416 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000080424/000008042424000083/pg-20240630.htm (Date: 2024-08-05)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_PG.txt
# DEBUG: Raw GPT output:
# ```json
# []
# ```
#   No new products extracted from GPT.
#
# === 21: NFLX (Netflix) - MarketCap: 393399533568 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001065280/000106528025000044/nflx-20241231.htm (Date: 2025-01-27)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_NFLX.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Ad-Supported Subscription Plan",
#         "product_description": "A lower-priced subscription plan that includes advertisements, aimed at meeting a variety of consumer needs."
#     },
#     {
#         "product_name": "Games",
#         "product_description": "An expansion of Netflix's entertainment video offering to include games, enhancing the overall user experience."
#     },
#     {
#         "product_name": "Live Programming",
#         "product_description": "A new feature that allows Netflix to offer live content, further diversifying its content offerings."
#     },
#     {
#         "product_name": "Consumer Products and Live Experiences",
#         "product_description": "An expansion into consumer products and live experiences to drive growth and enhance member engagement."
#     }
# ]
# ```
#   ✔ Found 4 new product(s). Writing to CSV...
#
# === 22: JNJ (Johnson & Johnson) - MarketCap: 392444116992 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000200406/000020040625000038/jnj-20241229.htm (Date: 2025-02-13)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_JNJ.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "CARVYKTI",
#         "product_description": "A chimeric antigen receptor (CAR)-T-cell therapy for the treatment of patients with relapsed/refractory multiple myeloma."
#     },
#     {
#         "product_name": "TECVAYLI",
#         "product_description": "A ready-to-use bispecific antibody for adults with relapsed or refractory multiple myeloma who have received at least four prior lines of therapy."
#     },
#     {
#         "product_name": "RYBREVANT",
#         "product_description": "In combination with chemotherapy for the first-line treatment of adult patients with advanced non-small cell lung cancer with activating EGFR exon 20 insertion mutations."
#     },
#     {
#         "product_name": "OPSYNVI",
#         "product_description": "A treatment for pulmonary arterial hypertension."
#     },
#     {
#         "product_name": "UPTRAVI",
#         "product_description": "An oral and intravenous, selective IP receptor agonist targeting a prostacyclin pathway in pulmonary arterial hypertension."
#     },
#     {
#         "product_name": "BALVERSA",
#         "product_description": "A treatment for patients with locally advanced or metastatic urothelial carcinoma and selected fibroblast growth factor receptor gene alterations."
#     },
#     {
#         "product_name": "V-Wave",
#         "product_description": "A device focused on developing innovative treatment options for patients with heart failure."
#     },
#     {
#         "product_name": "Ambrx",
#         "product_description": "A clinical-stage biopharmaceutical company with a proprietary synthetic biology technology platform to design and develop next-generation antibody drug conjugates (ADCs)."
#     },
#     {
#         "product_name": "Shockwave Medical",
#         "product_description": "Provider of innovative intravascular lithotripsy (IVL) technology for the treatment of calcified coronary artery disease (CAD) and peripheral artery disease (PAD)."
#     }
# ]
# ```
#   ✔ Found 9 new product(s). Writing to CSV...
#
# === 23: ABBV (AbbVie) - MarketCap: 374360113152 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001551152/000155115225000020/abbv-20241231.htm (Date: 2025-02-14)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_ABBV.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Elahere",
#         "product_description": "Elahere (mirvetuximab soravtansine-gynx) is an antibody-drug conjugate (ADC) used to treat certain types of cancer. Elahere is approved in both the United States and the European Union for the treatment of adult patients with FR positive, platinum-resistant epithelial ovarian, fallopian tube, or primary peritoneal cancer, who have received one to three prior systemic treatment regimens."
#     },
#     {
#         "product_name": "Epkinly",
#         "product_description": "Epkinly (epcoritamab) is a product used to treat adults with certain types of diffuse large B-cell lymphoma (DLBCL) and high-grade B-cell lymphoma that has recurred or that does not respond to previous treatment after receiving two or more treatments. Epkinly is administered as a subcutaneous injection."
#     },
#     {
#         "product_name": "Skyrizi",
#         "product_description": "Skyrizi (risankizumab) is an interleukin-23 (IL-23) inhibitor that selectively blocks IL-23 by binding to its p19 subunit. It is a biologic therapy approved to treat the following autoimmune diseases in North America, the European Union and Japan: plaque psoriasis, psoriatic arthritis, Crohn's disease, and ulcerative colitis."
#     },
#     {
#         "product_name": "Rinvoq",
#         "product_description": "Rinvoq (upadacitinib) is an oral, once-daily selective and reversible JAK inhibitor that is approved to treat various inflammatory diseases including rheumatoid arthritis, psoriatic arthritis, atopic dermatitis, and ulcerative colitis."
#     },
#     {
#         "product_name": "Juvederm Voluma XC",
#         "product_description": "Juvederm Voluma XC is an injectable filler approved for injection in the temple region to improve moderate to severe temple hollowing in adults over the age of 21."
#     },
#     {
#         "product_name": "Produodopa",
#         "product_description": "Produodopa (ABBV-951) is a subcutaneous 24-hour infusion of levodopa-based therapy for the treatment of advanced Parkinson's disease with severe motor fluctuations and hyperkinesia or dyskinesia."
#     },
#     {
#         "product_name": "Vyalev",
#         "product_description": "Vyalev (ABBV-951) is a subcutaneous 24-hour infusion of levodopa-based therapy approved for the treatment of motor fluctuations in adults with advanced Parkinson's disease."
#     },
#     {
#         "product_name": "Qulipta",
#         "product_description": "Qulipta (atogepant) is a calcitonin gene-related peptide receptor antagonist indicated for the preventive treatment of episodic and chronic migraine in adults."
#     }
# ]
# ```
#   ✔ Found 8 new product(s). Writing to CSV...
#
# === 24: HD (Home Depot (The)) - MarketCap: 362309287936 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000354950/000035495025000085/hd-20250202.htm (Date: 2025-03-21)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_HD.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "SRS Distribution",
#         "product_description": "A leading residential specialty trade distribution company engaged in the distribution of residential and commercial roofing products, complementary building products, landscape supplies, and swimming pool supplies serving the professional roofer, landscaper, and pool contractor."
#     }
# ]
# ```
#   ✔ Found 1 new product(s). Writing to CSV...
#
# === 25: BAC (Bank of America) - MarketCap: 303427747840 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000070858/000007085825000139/bac-20241231.htm (Date: 2025-02-25)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_BAC.txt
#   ❌ GPT Extraction Error: Error code: 429 - {'error': {'message': 'Request too large for gpt-4o-mini in organization org-PMyKV597a0bS1G4IezkF85A5 on tokens per min (TPM): Limit 200000, Requested 214782. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#   No new products extracted from GPT.
#
# === 26: KO (Coca-Cola Company (The)) - MarketCap: 300811976704 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000021344/000002134425000011/ko-20241231.htm (Date: 2025-02-20)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_KO.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "BodyArmor",
#         "product_description": "A line of sports performance and hydration beverages acquired by The Coca-Cola Company, which offers a variety of options for consumers."
#     },
#     {
#         "product_name": "Jack Daniels & Coca-Cola",
#         "product_description": "A pre-mixed cocktail that combines Jack Daniels whiskey with Coca-Cola, introduced as part of the Company's entry into the alcohol beverage category."
#     },
#     {
#         "product_name": "Lemon-Dou",
#         "product_description": "A flavored alcohol beverage introduced by The Coca-Cola Company as part of its expansion into the alcohol beverage category."
#     },
#     {
#         "product_name": "Topo Chico Hard Seltzer",
#         "product_description": "A hard seltzer product launched by The Coca-Cola Company, expanding its portfolio into the alcoholic beverage market."
#     }
# ]
# ```
#   ✔ Found 4 new product(s). Writing to CSV...
#
# === 27: TMUS (T-Mobile US) - MarketCap: 291840163840 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001283699/000128369925000012/tmus-20241231.htm (Date: 2025-01-31)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_TMUS.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "High Speed Internet",
#         "product_description": "A fixed wireless product that utilizes the excess capacity of T-Mobile's nationwide 5G network, providing an alternative to traditional landline internet or broadband service providers."
#     },
#     {
#         "product_name": "Go5G Plus",
#         "product_description": "A service plan offering unlimited talk, text, and data on T-Mobile's network, including 5G access at no extra cost, scam protection features, and access to the same device offers as new customers."
#     },
#     {
#         "product_name": "T-Life app",
#         "product_description": "A comprehensive app designed to tap into customer preferences and radically simplify customer experiences in the future."
#     },
#     {
#         "product_name": "5G Advanced Network Solutions (ANS)",
#         "product_description": "Specialized network solutions aimed at enterprises, leveraging T-Mobile's advanced 5G capabilities."
#     },
#     {
#         "product_name": "T-Priority",
#         "product_description": "A network slicing solution designed for first responders, providing prioritized access to network resources."
#     }
# ]
# ```
#   ✔ Found 5 new product(s). Writing to CSV...
#
# === 28: CRM (Salesforce) - MarketCap: 273481367552 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001108524/000110852425000006/crm-20250131.htm (Date: 2025-03-05)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_CRM.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Agentforce",
#         "product_description": "Agentforce is the agentic layer of the Salesforce Platform for deploying autonomous AI agents across business functions. It includes a set of tools to create and customize AI agents, as well as a library of ready-to-use skills for various use cases across sales, service, marketing, and commerce."
#     }
# ]
# ```
#   ✔ Found 1 new product(s). Writing to CSV...
#
# === 29: CVX (Chevron Corporation) - MarketCap: 268790808576 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000093410/000009341025000009/cvx-20241231.htm (Date: 2025-02-21)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_CVX.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Solar-to-Hydrogen Production Project",
#         "product_description": "Chevron announced its first solar-to-hydrogen production project in Kern County, which will create lower carbon hydrogen through electrolysis, utilizing solar power, land and non-potable produced water from Chevron's existing assets."
#     },
#     {
#         "product_name": "Advanced Clean Energy Storage Project",
#         "product_description": "Chevron owns a majority interest in ACES Delta, LLC, a joint venture developing the Advanced Clean Energy Storage Project in Delta, Utah. The project, currently under construction, is designed to produce hydrogen made from renewable energy, store that hydrogen in two salt caverns, and deliver it as needed to hydrogen-capable gas turbines to generate power."
#     },
#     {
#         "product_name": "Geismar Renewable Diesel Plant Expansion",
#         "product_description": "Expansion work at the Geismar renewable diesel plant in Louisiana to increase production capacity from 7,000 to 22,000 barrels per day is in final commissioning stage, with startup expected in the first quarter."
#     },
#     {
#         "product_name": "Digital Scholar Program",
#         "product_description": "Chevron offers the Digital Scholar Program, preparing employees with advanced technology skills through one-year Master of Science degrees in Engineering and Management."
#     }
# ]
# ```
#   ✔ Found 4 new product(s). Writing to CSV...
#
# === 30: CSCO (Cisco) - MarketCap: 240527409152 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000858877/000085887724000017/csco-20240727.htm (Date: 2024-09-05)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_CSCO.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Splunk Acquisition",
#         "product_description": "In March 2023, Cisco completed the acquisition of Splunk Inc., a public cybersecurity and observability company, for approximately $27 billion. This acquisition included significant intangible assets, including customer-related assets and technology."
#     }
# ]
# ```
#   ✔ Found 1 new product(s). Writing to CSV...
#
# === 31: MRK (Merck & Co.) - MarketCap: 235805835264 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000310158/000162828025007732/mrk-20241231.htm (Date: 2025-02-25)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_MRK.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Winrevair",
#         "product_description": "A novel activin signaling inhibitor indicated for the treatment of adults with pulmonary arterial hypertension (PAH) to increase exercise capacity, improve WHO functional class and reduce the risk of clinical worsening events."
#     },
#     {
#         "product_name": "Capvaxive",
#         "product_description": "A 21-valent pneumococcal conjugate vaccine designed to help prevent invasive pneumococcal disease and pneumococcal pneumonia caused by certain serotypes in adults."
#     }
# ]
# ```
#   ✔ Found 2 new product(s). Writing to CSV...
#
# === 32: PM (Philip Morris International) - MarketCap: 235281432576 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001413329/000141332925000013/pm-20241231.htm (Date: 2025-02-06)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_PM.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "IQOS",
#         "product_description": "A heat-not-burn product that uses a precisely controlled heating device into which a specially designed and proprietary tobacco unit is inserted and heated to generate an aerosol."
#     },
#     {
#         "product_name": "ZYN",
#         "product_description": "A leading brand of nicotine pouches that are available in various flavors and are designed for oral use without combustion."
#     },
#     {
#         "product_name": "BONDS by IQOS",
#         "product_description": "A heat-not-burn product that utilizes external resistive heating technology, commercialized in the Philippines and Colombia."
#     },
#     {
#         "product_name": "VEEV",
#         "product_description": "A brand of vaping products that are battery-powered devices producing an aerosol by vaporizing a tobacco-free liquid solution."
#     }
# ]
# ```
#   ✔ Found 4 new product(s). Writing to CSV...
#
# === 33: IBM (IBM) - MarketCap: 231472922624 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000051143/000005114325000015/ibm-20241231.htm (Date: 2025-02-25)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_IBM.txt
# DEBUG: Raw GPT output:
# ```json
# []
# ```
#   No new products extracted from GPT.
#
# === 34: WFC (Wells Fargo) - MarketCap: 226654928896 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000072971/000007297125000066/wfc-20241231.htm (Date: 2025-02-25)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_WFC.txt
# DEBUG: Raw GPT output:
# ```json
# []
# ```
#   No new products extracted from GPT.
#
# === 35: ABT (Abbott Laboratories) - MarketCap: 225947205632 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000001800/000162828025007110/abt-20241231.htm (Date: 2025-02-21)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_ABT.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Lingo",
#         "product_description": "A new over-the-counter continuous glucose monitoring (CGM) system based on Abbott's FreeStyle Libre CGM technology."
#     },
#     {
#         "product_name": "Libre Rio",
# ...
#         "product_description": "Louisiana-based insurance brokers offering business insurance, employee benefits, and alternative risk financing consulting, acquired in March."
#     },
#     {
#         "product_name": "Louisiana Companies",
#         "product_description": "Provides business and personal lines insurance to businesses and individuals, acquired in March."
#     },
#     {
#         "product_name": "AC Risk Management",
#         "product_description": "A New York-based commercial lines insurance broker primarily offering property and casualty insurance to businesses, acquired in May."
#     },
#     {
#         "product_name": "Perkins Insurance Agencies LLC",
#         "product_description": "A Texas-based insurance broker providing commercial property and casualty and personal lines coverage, acquired in May."
#     },
#     {
#         "product_name": "Fisher Brown Bottrell Insurance, Inc. (FBBI)",
#         "product_description": "A Mississippi-based insurance broker providing commercial property and casualty insurance, surety and employee benefits services, acquired in May."
#     },
#     {
#         "product_name": "AmeriStar Agency Inc.",
#         "product_description": "A Minnesota-based insurance broker offering insurance coverage solutions to high-net-worth individuals and commercial clients, acquired in July."
#     },
#     {
#         "product_name": "Hudson Shore Group",
#         "product_description": "A New Jersey-based public and private sector employee benefits broker specializing in public sector clients, acquired in July."
#     },
#     {
#         "product_name": "The Horton Group, Inc.",
#         "product_description": "An Illinois-based insurance broker that offers property and casualty insurance, employee benefits consultation, and personal lines coverage, acquired in August."
#     },
#     {
#         "product_name": "Acumen Solutions Group, LLC",
#         "product_description": "A New York-based insurance broker offering customized insurance programs to businesses and individuals, acquired in December."
#     },
#     {
#         "product_name": "SeaTec Consulting Inc.",
#         "product_description": "A Georgia-based firm providing consulting, engineering, and digital expertise across the aviation, aerospace and defense, and transportation industries, acquired in February."
#     },
#     {
#         "product_name": "Vanguard's Institutional Advisory Services business unit",
#         "product_description": "A Pennsylvania-based outsourced chief investment officer business providing investment management services for not-for-profit organizations and other institutional investors, acquired in March."
#     },
#     {
#         "product_name": "The Talent Enterprise",
#         "product_description": "A United Arab Emirates-based psychometric and talent assessment technology company providing talent assessment tools and talent capability development solutions, acquired in March."
#     },
#     {
#         "product_name": "Innopay NL B.V.",
#         "product_description": "A Netherlands-based consultancy firm delivering strategy, scheme development, and execution in the domain of digital payments, acquired in March."
#     },
#     {
#         "product_name": "Veritas Total Solutions",
#         "product_description": "A Texas-based commodity trading advisory firm with expertise in risk, systems, analytics and artificial intelligence, acquired in July."
#     },
#     {
#         "product_name": "hkp///group",
#         "product_description": "A Germany-based human resources and corporate governance consulting firm advising clients throughout Germany and the Netherlands, acquired in October."
#     },
#     {
#         "product_name": "Gerolamo Holding S.R.L. (Cardano)",
#         "product_description": "A Luxembourg-based pension services, advisory and investment solutions firm, acquired in November."
#     }
# ]
# ```
#   ✔ Found 18 new product(s). Writing to CSV...
#
# === 91: SBUX (Starbucks) - MarketCap: 112104931328 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000829224/000082922424000057/sbux-20240929.htm (Date: 2024-11-20)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_SBUX.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "23.5 Degrees",
#         "product_description": "A U.K. licensed business partner acquired to expand Starbucks' portfolio of company-operated stores and enhance the coffeehouse experience for customers, converting 113 licensed stores to company-operated stores."
#     }
# ]
# ```
#   ✔ Found 1 new product(s). Writing to CSV...
#
# === 92: NKE (Nike, Inc.) - MarketCap: 108834390016 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000320187/000032018724000044/nke-20240531.htm (Date: 2024-07-25)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_NKE.txt
# DEBUG: Raw GPT output:
# ```json
# []
# ```
#   No new products extracted from GPT.
#
# === 93: LMT (Lockheed Martin) - MarketCap: 108630638592 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000936468/000093646825000009/lmt-20241231.htm (Date: 2025-01-28)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_LMT.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Terran Orbital Corporation",
#         "product_description": "Acquisition of Terran Orbital Corporation for a purchase consideration of $314 million, which will be included in the Space business segment. Terran Orbital's product and service offerings include satellite design, production, launch planning, mission operations, and on-orbit support for the aerospace and defense industries."
#     },
#     {
#         "product_name": "X-62A (F-16)",
#         "product_description": "Demonstrating autonomous capabilities with the X-62A (F-16)."
#     },
#     {
#         "product_name": "BLACK HAWK",
#         "product_description": "Demonstrating autonomous capabilities with the optionally piloted BLACK HAWK."
#     },
#     {
#         "product_name": "CH-53K King Stallion",
#         "product_description": "Radar surveillance systems and CH-53K King Stallion heavy lift helicopter."
#     },
#     {
#         "product_name": "Next Generation Overhead Persistent Infrared (Next Gen OPIR)",
#         "product_description": "System providing the U.S. Space Force with enhanced worldwide missile warning capabilities."
#     },
#     {
#         "product_name": "Next Generation Interceptor (NGI)",
#         "product_description": "Program with the Missile Defense Agency utilizing next generation propulsion and sensors to provide homeland missile defense."
#     },
#     {
#         "product_name": "Transport Layer programs",
#         "product_description": "Small satellite capabilities to support proliferated space constellations and early warning communications for the Space Development Agency."
#     }
# ]
# ```
#   ✔ Found 7 new product(s). Writing to CSV...
#
# === 94: PLD (Prologis) - MarketCap: 107265515520 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001045609/000095017025021272/pld-20241231.htm (Date: 2025-02-14)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_PLD.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Prologis Essentials",
#         "product_description": "Through Prologis Essentials, we provide solutions to meet our customers operations and energy and sustainability needs. Our customer experience teams, proprietary technology and strategic partnerships are foundational to all aspects of our Prologis Essentials offerings."
#     },
#     {
#         "product_name": "LED and SolarSmart solutions",
#         "product_description": "Prologis Essentials LED and SolarSmart solutions provide our customers with energy solutions and savings through efficient lighting and solar panels on our rooftops."
#     }
# ]
# ```
#   ✔ Found 2 new product(s). Writing to CSV...
#
# === 95: MU (Micron Technology) - MarketCap: 106559217664 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000723125/000072312524000027/mu-20240829.htm (Date: 2024-10-04)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_MU.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "1 (1-beta) DRAM",
#         "product_description": "The industry’s first 1 (1-beta) production node, which offers further improvements in power efficiency and bit density."
#     },
#     {
#         "product_name": "1 (1-gamma) DRAM",
#         "product_description": "Next generation of DRAM expected for volume shipments, employing EUV lithography production."
#     },
#     {
#         "product_name": "128GB DDR5 server module",
#         "product_description": "Built on a monolithic 32Gb DRAM die, this innovative product provides an industry alternative to existing 3D TSV-based solutions for memory-intensive generative AI applications."
#     },
#     {
#         "product_name": "256GB MRDIMM module",
#         "product_description": "Enhances performance and increases DRAM content per server."
#     },
#     {
#         "product_name": "Low-power compression-attached memory module",
#         "product_description": "Designed to deliver the required performance to process AI workloads on PCs."
#     },
#     {
#         "product_name": "GDDR7 graphics memory",
#         "product_description": "Next generation GDDR memory that delivers high-performance memory in a power-optimized design."
#     },
#     {
#         "product_name": "Micron G8 NAND",
#         "product_description": "The industry’s first eighth-generation NAND, featuring higher areal density and improved energy efficiency."
#     },
#     {
#         "product_name": "Micron G9 NAND",
#         "product_description": "Representative of the industry's ninth-generation 3D NAND node, ramping in high volume."
#     },
#     {
#         "product_name": "Micron G9 TLC based NAND",
#         "product_description": "Designed to deliver the transfer rates required for low-latency and high-throughput needs of data-centric workloads."
#     },
#     {
#         "product_name": "8-high 24GB HBM3E",
#         "product_description": "Increased bandwidth and superior power efficiency enabled by advanced 1 process node."
#     },
#     {
#         "product_name": "12-high 36GB HBM3E",
#         "product_description": "Production-capable units to enable qualifications across the AI ecosystem."
#     },
#     {
#         "product_name": "Second generation of NAND UFS 4.0 devices",
#         "product_description": "Offers a more compact package size and increased power efficiency for next generation smartphone designs."
#     },
#     {
#         "product_name": "Next generation low power smartphone DRAM (LPDDR5X)",
#         "product_description": "Provides peak bandwidth data transfer critical for enabling AI at the intelligent edge."
#     }
# ]
# ```
#   ✔ Found 13 new product(s). Writing to CSV...
#
# === 96: KKR (KKR) - MarketCap: 105542811648 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001404912/000140491225000015/kkr-20241231.htm (Date: 2025-02-28)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_KKR.txt
#   ❌ GPT Extraction Error: Error code: 429 - {'error': {'message': 'Request too large for gpt-4o-mini in organization org-PMyKV597a0bS1G4IezkF85A5 on tokens per min (TPM): Limit 200000, Requested 409055. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#   No new products extracted from GPT.
#
# === 97: ADI (Analog Devices) - MarketCap: 102478561280 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000006281/000000628124000204/adi-20241102.htm (Date: 2024-11-26)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_ADI.txt
# DEBUG: Raw GPT output:
# ```json
# []
# ```
#   No new products extracted from GPT.
#
# === 98: ANET (Arista Networks) - MarketCap: 101204877312 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001596532/000159653225000028/anet-20241231.htm (Date: 2025-02-19)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_ANET.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Arista Autonomous Virtual Assist (AVA TM)",
#         "product_description": "Arista offers customers the Arista Autonomous Virtual Assist (AVA TM) which uses natural processing language to provide AI-assisted outcomes for network operations, security and observability."
#     },
#     {
#         "product_name": "Arista Etherlink AI portfolio",
#         "product_description": "The Arista Etherlink AI portfolio of 800G switches, coupled with Arista's EOS innovations such as AI Analyzer along with optimal load balancing solutions, offer compelling solutions for contemporary AI applications and deployment."
#     },
#     {
#         "product_name": "Arista 7800R AI Spine and AI Leaf",
#         "product_description": "The Arista 7800R AI Spine and AI Leaf are designed to address the demanding scale and performance requirements driven by large-scale AI networks."
#     },
#     {
#         "product_name": "Arista 7700R4 Distributed Etherlink Switch (DES)",
#         "product_description": "The Arista 7700R4 DES is an ultra-scalable, intelligent distributed system engineered to meet the rigorous demands of large-scale AI and machine learning (ML) environments."
#     },
#     {
#         "product_name": "Cognitive Campus Switching",
#         "product_description": "Arista's Cognitive Campus switching products, powered by EOS, offer consistent, unified management across the campus edge for wired and wireless networks as well as integrated security & proactive network assurance."
#     },
#     {
#         "product_name": "Cloud-Grade Routing",
#         "product_description": "Arista's Cloud-Grade Routing platforms, powered by EOS, combine high performance routing, high port density, deep buffers, integrated DWDM and wire speed encryption."
#     },
#     {
#         "product_name": "WAN Routing - Arista AWE-7200R Series",
#         "product_description": "The Arista AWE-7200R Series of WAN Routing System, purpose built by Arista and powered by Arista EOS, offers high performance and scale to meet enterprise modern WAN edge and aggregation requirements."
#     },
#     {
#         "product_name": "CloudEOS",
#         "product_description": "CloudEOS is Arista's multi-cloud and cloud-native networking solution supporting autonomic operation to deliver an enterprise-class, highly secure, and reliable networking experience for any cloud."
#     }
# ]
# ```
#   ✔ Found 8 new product(s). Writing to CSV...
#
# === 99: UPS (United Parcel Service) - MarketCap: 98451873792 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0001090727/000109072725000019/ups-20241231.htm (Date: 2025-02-18)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_UPS.txt
# DEBUG: Raw GPT output:
# ```json
# [
#     {
#         "product_name": "Smart Package Smart Facility",
#         "product_description": "A technology initiative leveraging RFID technology to enhance package visibility and reduce manual scans in UPS's logistics network."
#     },
#     {
#         "product_name": "UPS SurePost",
#         "product_description": "A residential ground service for non-urgent, lightweight residential shipments, which has been insourced to provide greater operational control and maintain service quality."
#     },
#     {
#         "product_name": "Frigo-Trans",
#         "product_description": "An industry-leading, complex healthcare logistics provider based in Germany, acquired to enhance UPS's cold-chain logistics capabilities."
#     },
#     {
#         "product_name": "Happy Returns",
#         "product_description": "A technology-focused company providing innovative end-to-end return services, acquired to enhance UPS's logistics offerings."
#     },
#     {
#         "product_name": "Estafeta",
#         "product_description": "A leading domestic small package provider in Mexico, with an acquisition expected to close in the first half of 2024."
#     }
# ]
# ```
#   ✔ Found 5 new product(s). Writing to CSV...
#
# === 100: LRCX (Lam Research) - MarketCap: 98315517952 ===
#   Found 10-K: https://www.sec.gov/Archives/edgar/data/0000707549/000070754924000106/lrcx-20240630.htm (Date: 2024-08-29)
#   ✔ Saved cleaned text to: 10k_cleaned_files/10k_LRCX.txt
# DEBUG: Raw GPT output:
# ```json
# []
# ```
#   No new products extracted from GPT.
